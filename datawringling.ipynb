# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.columns
#
# NameError: name 'data' is not defined

# %%
#count of people who survived in a passenger class 
grouped=data.groupby("Pclass")["Surived"].agg("count")
print(grouped)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #count of people who survived in a passenger class
# ----> 2 grouped=data.groupby("Pclass")["Surived"].agg("count")
#       3 print(grouped)
#
# NameError: name 'data' is not defined

# %% [markdown]
# #by group
# grouped=data.groupby("Pclass")["Surived"].agg("count")
# print(grouped)

# %%
#filter the data to the people who only survived
#find the survival rate of each passenger class /per passenger class
grouped=data.groupby("Pclass")["Surived"].agg("mean")
print(grouped)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 #filter the data to the people who only survived
#       2 #find the survival rate of each passenger class /per passenger class
# ----> 3 grouped=data.groupby("Pclass")["Surived"].agg("mean")
#       4 print(grouped)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# ...

# %%
#lets define first the data 
data=pd.read_csv("titanic.csv")
##lets define first the data 
#check this errors below

#data=pd.read_csv("titanic.csv")
NameError                                 Traceback (most recent call last)
Cell In[4], line 2
      1 #lets define first the data 
----> 2 data=pd.read_csv("titanic.csv")

NameError: name 'pd' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #lets define first the data
# ----> 2 data=pd.read_csv("titanic.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# Now read the CSV
data = pd.read_csv("tested.csv")

#dictionary

# %%
# Filter data for survivors
survivors = data[data["Survived"] == 1]

# Find survival rate per passenger class
grouped = data.groupby("Pclass")["Survived"].mean()
print(grouped)
# Out:
# Pclass
# 1    0.467290
# 2    0.322581
# 3    0.330275
# Name: Survived, dtype: float64

# %%
dict1={
    "id":[1,2,3,4,5],
    "name":["kipngeno","atasaa","nelle","melomelo","wambua"],
}

# %%
dict2={
    "id":[1,2,3,4,5],
    "fruit":["mango","banana","pawpaw","apple","avocado"]
}

# %%
import pandas as pd

data1 = pd.DataFrame(dict1)
print(data1.head())
# Out:
#    id      name
# 0   1  kipngeno
# 1   2    atasaa
# 2   3     nelle
# 3   4  melomelo
# 4   5    wambua

# %%
import pandas as pd

data2 = pd.DataFrame(dict2)
print(data2.head())
# Out:
#    id    fruit
# 0   1    mango
# 1   2   banana
# 2   3   pawpaw
# 3   4    apple
# 4   5  avocado

# %%
merged=pd.merge(data1,data2, on="id", how="left")

# %%
merged.head()
# Out:
#    id      name    fruit
# 0   1  kipngeno    mango
# 1   2    atasaa   banana
# 2   3     nelle   pawpaw
# 3   4  melomelo    apple
# 4   5    wambua  avocado

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[3,4,5,6,7]

# %%
plt.plot(x,y)
plt.title("line chart")
plt.show()

# %%
#histogram for age 
plt.hist(data["Age"],bins =20)
plt.title("age distribution")
plt.xlabel("age")
plt.ylabel("frequency")
plt.show()

# %%
import seaborn as sns
sns.histplot(data,x="Age", kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Box plot
#works with numerical column
#assits with distribution
sns.boxplot (data=data, x="Pclass", y="Age")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#countplot
#for categorical columns
sns.countplot (data=data, x="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.boxplot (data=data, x="Pclass", y="Fare")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>
